# %% [markdown]
# <a href="https://colab.research.google.com/github/GrCOTE7/python/blob/master/tutos/machinelearnia/0_for_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <a href="https://colab.research.google.com/github/GrCOTE7/python/blob/master/tutos/machinelearnia/0_for_test.ipynb" target="_parent">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %%
import time

delay = 5 ← Tu veux attendre cb de tps ?

t = time.sleep(3)
print(f'Fini d\'attendre {delay} seconde{"s" if delay>1 else ""} !')
# Out:
# Fini d'attendre 5 secondes !
