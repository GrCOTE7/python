# %% [markdown]
# <a href="https://colab.research.google.com/github/GrCOTE7/deep_learning_course/blob/main/D:/Py/tutos/machinelearnia/0_for_test.ipynb" target="_parent">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %%
import time
    
time.sleep(3)
