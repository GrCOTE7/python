# %% [markdown]
# 2 listes et 2 fonctions in list

# %%
import random

def generateVars():
  global x, myUnicItemsList, myList
  x = random.randint(1, 11)

  myUnicItemsList = random.sample(range(1, 11), 10)
  myList = [random.randint(1, 10) for _ in range(10)]

  # print(x, myUnicItemsList, myList, sep='\n')
  print(x, myList, sep='\n')

# %%
def natiFunc(): return x in myList

# %%
def myFunc(): 
  for i in myList:
    return 'True aussi' if i == x else 'False aussi'

# %%
generateVars()
print (f"{natiFunc() = } vs {myFunc() = }")
# Out:
# 8
# [8, 5, 10, 8, 2, 5, 3, 8, 4, 6]
# natiFunc() = True vs myFunc() = 'True aussi'
