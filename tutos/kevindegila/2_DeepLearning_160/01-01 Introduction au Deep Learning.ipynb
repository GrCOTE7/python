# %% [markdown]
# <a href="https://colab.research.google.com/github/GrCOTE7/deep_learning_course/blob/gc7/01-01%20Introduction%20au%20Deep%20Learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from top import Top

t = Top()
t.start()

# %% [markdown]
# # Intro au Deep Learning (By Kevin Degila)
#
# Ce code correspond à la vidéo #7 d'une [série de 160 épisodes](https://www.youtube.com/watch?v=XXyMPp_IwXg&list=PL049bGjkT7dIARLPrxvA4-tbEcg6k0UDX&index=7)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import SGD

# %%
import pandas as pd
import numpy as np

data_url = "http://lib.stat.cmu.edu/datasets/boston"
raw_df = pd.read_csv(data_url, sep=r"\s+", skiprows=22, header=None)
data = np.hstack([raw_df.values[::2, :], raw_df.values[1::2, :2]])
target = raw_df.values[1::2, 2]

# Scaling the data
from sklearn.preprocessing import StandardScaler
s = StandardScaler()
data = s.fit_transform(data)
target = target.reshape((-1, 1))

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data, target, test_size=0.3, random_state=80718)

# %%
data.shape
# Out:
# (506, 13)

# %%
lr = Sequential([Dense(units=1, activation='relu')])
lr.compile(optimizer=SGD(learning_rate=0.1), loss='mae')
history = lr.fit(X_train, y_train, epochs=50, validation_data=(X_test, y_test))
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Epoch 1/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 21.9479 - val_loss: 20.8216
# Epoch 2/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 20.8883 - val_loss: 19.4426
# Epoch 3/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 19.2159 - val_loss: 17.7937
# Epoch 4/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 17.4751 - val_loss: 16.0127
# Epoch 5/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 15.5905 - val_loss: 14.3910
# Epoch 6/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 14.0603 - val_loss: 12.9116
# Epoch 7/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 12.7881 - val_loss: 12.1907
# Epoch 8/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 12.0775 - val_loss: 11.7002
# Epoch 9/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 11.5801 - val_loss: 11.1506
# Epoch 10/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 11.0575 - val_loss: 10.7519
# Epoch 11/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 10.6774 - val_loss: 10.3232
# Epoch 12/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 10.3323 - val_loss: 10.0920
# Epoch 13/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 10.0561 - val_loss: 9.7459
# Epoch 14/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.7452 - val_loss: 9.3994
# Epoch 15/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.4730 - val_loss: 9.1360
# Epoch 16/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.2703 - val_loss: 8.8853
# Epoch 17/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.0371 - val_loss: 8.7566
# Epoch 18/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.8475 - val_loss: 8.4350
# Epoch 19/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.5695 - val_loss: 8.1661
# Epoch 20/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.3463 - val_loss: 8.0681
# Epoch 21/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.1837 - val_loss: 7.8150
# Epoch 22/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.9648 - val_loss: 7.6601
# Epoch 23/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.8290 - val_loss: 7.5861
# Epoch 24/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.7125 - val_loss: 7.3843
# Epoch 25/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.5875 - val_loss: 7.3124
# Epoch 26/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.5052 - val_loss: 7.2226
# Epoch 27/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.4349 - val_loss: 7.1168
# Epoch 28/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.3826 - val_loss: 7.1323
# Epoch 29/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.3027 - val_loss: 7.0863
# Epoch 30/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.2474 - val_loss: 7.0180
# Epoch 31/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.1851 - val_loss: 6.9770
# Epoch 32/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.1310 - val_loss: 6.9733
# Epoch 33/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.0814 - val_loss: 6.8994
# Epoch 34/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.0280 - val_loss: 6.7632
# Epoch 35/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.9869 - val_loss: 6.6994
# Epoch 36/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.9611 - val_loss: 6.6871
# Epoch 37/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.8958 - val_loss: 6.6697
# Epoch 38/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.8509 - val_loss: 6.7632
# Epoch 39/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.8187 - val_loss: 6.6582
# Epoch 40/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.7757 - val_loss: 6.6080
# Epoch 41/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.7365 - val_loss: 6.5633
# Epoch 42/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.7030 - val_loss: 6.5751
# Epoch 43/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.6675 - val_loss: 6.5432
# Epoch 44/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.6271 - val_loss: 6.5651
# Epoch 45/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.5930 - val_loss: 6.4944
# Epoch 46/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.5559 - val_loss: 6.4632
# Epoch 47/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.5226 - val_loss: 6.4135
# Epoch 48/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.4943 - val_loss: 6.5142
# Epoch 49/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.4595 - val_loss: 6.3484
# Epoch 50/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.4250 - val_loss: 6.3158

# %%
lr
# Out:
# <Sequential name=sequential, built=True>

# %% [markdown]
# # Premier Exemple d'apprentissage

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.DataFrame([ {"n_chambres" : 2, "prix" : 10}, {"n_chambres" : 4, "prix" : 20}])
data
# Out:
#    n_chambres  prix
# 0           2    10
# 1           4    20

# %%
plt.scatter(data["n_chambres"], data['prix'], c="r")
plt.show()

# %% [markdown]
# prix = 5 * n_chambres

# %%
# y = 5 x

plt.scatter(data["n_chambres"], data['prix'], c="r")
plt.plot(data["n_chambres"], data['prix'])
plt.xlabel('Nombre de chambres')
plt.ylabel('Prix')
plt.show()

# %%
# entree  + instruction = sortie

# entree + sortie  == instruction ou les regles

# y= 5 x  model

# %%
data = pd.DataFrame([ {"n_chambres" : 2, "prix" : 10}, {"n_chambres" : 4, "prix" : 20},
                    {"n_chambres" : 3, "prix" : 15},
                     {"n_chambres" : 3, "prix" : 20},
                     {"n_chambres" : 1, "prix" : 3.5},
                    {"n_chambres" : 6, "prix" : 31},
                     {"n_chambres" : 5, "prix" : 33},
                    {"n_chambres" : 8, "prix" : 36},
                    {"n_chambres" : 7, "prix" : 50},
                    {"n_chambres" : 9, "prix" : 42},
                    ])
data
# Out:
#    n_chambres  prix
# 0           2  10.0
# 1           4  20.0
# 2           3  15.0
# 3           3  20.0
# 4           1   3.5
# 5           6  31.0
# 6           5  33.0
# 7           8  36.0
# 8           7  50.0
# 9           9  42.0

# %%
plt.scatter(data["n_chambres"], data['prix'], c="r")
plt.plot(data["n_chambres"], data['n_chambres'] * 5)
plt.xlabel('Nombre de chambres')
plt.ylabel('Prix')
plt.show()

# %%
# x = n_chambres
# y = Prix

# %%
def model(x, w):
  return w * x

# %%
model(x=3, w=5) # y= 5x
# Out:
# 15

# %%
# y= 6x
model(x=3, w=6)
# Out:
# 18

# %%
def erreur(x, w, y):
  y_model = model(x, w)

  distance = (y - y_model) **2

  return np.sum(distance)

# %%
# x = 6, y = 54

# y = 5x, w = 5

# %%
erreur(x=6, w=5, y=54)
# Out:
# np.int64(576)

# %%
# y_model = 5 * 6 = 30

distance = (54 - 30)**2

# %%
data['n_chambres'].values
# Out:
# array([2, 4, 3, 3, 1, 6, 5, 8, 7, 9])

# %%
n_chambres = data['n_chambres'].values
prix = data['prix'].values

# %%
erreur(x=n_chambres, w=5, y=prix) # y = 5 x
# Out:
# np.float64(342.25)

# %%
plt.scatter(data["n_chambres"], data['prix'], c="r")
plt.plot(data["n_chambres"], data['n_chambres'] * 5)
plt.plot(data["n_chambres"], data['n_chambres'] * 4)
plt.xlabel('Nombre de chambrees')
plt.ylabel('Prix')
plt.show()

# %%
erreur(x=n_chambres, w=4, y=prix)
# Out:
# np.float64(847.25)

# %%
plt.scatter(data["n_chambres"], data['prix'], c="r")
plt.plot(data["n_chambres"], data['n_chambres'] * 5, label='w=5')
plt.plot(data["n_chambres"], data['n_chambres'] * 4, label='w=4')
plt.plot(data["n_chambres"], data['n_chambres'] * 6, label='w=6')
plt.xlabel('Nombre de chambrees')
plt.ylabel('Prix')
plt.legend()
plt.show()

# %%
erreur(x=n_chambres, w=6, y=prix)
# Out:
# np.float64(425.25)

# %%
erreur(x=n_chambres, w=4.9, y=prix)
# Out:
# np.float64(366.2899999999999)

# %%
f"w = 5 : {erreur(x=n_chambres, w=5.1, y=prix)}", f"w = 5.1 : {erreur(x=n_chambres, w=5, y=prix)}"
# Out:
# ('w = 5 : 324.0900000000001', 'w = 5.1 : 342.25')

# %%
plt.scatter(data["n_chambres"], data['prix'], c="r")
plt.plot(data["n_chambres"], data['n_chambres'] * 5, c='c', label="w=5")
plt.plot(data["n_chambres"], data['n_chambres'] * 5.1, c='g', label="w=5.1")
plt.xlabel('Nombre de chambres')
plt.ylabel('Prix')
plt.legend()
plt.show()

# %%
erreur(x=n_chambres, w=5.2, y=prix) #y=5.2 x
# Out:
# np.float64(311.81000000000006)

# %%
erreur(x=n_chambres, w=5.3, y=prix)
# Out:
# np.float64(305.4099999999999)

# %%
erreur(x=n_chambres, w=5.4, y=prix) #y = 5.4x
# Out:
# np.float64(304.88999999999993)

# %%
erreur(x=n_chambres, w=5.5, y=prix)
# Out:
# np.float64(310.25)

# %%
erreur(x=n_chambres, w=5.6, y=prix)
# Out:
# np.float64(321.49)

# %%
plt.scatter(data["n_chambres"], data['prix'], c="r")
plt.plot(data["n_chambres"], data['n_chambres'] * 5, label='w=5')
plt.plot(data["n_chambres"], data['n_chambres'] * 5.4, label='w=5.4')

plt.xlabel('Nombre de chambres')
plt.ylabel('Prix')
plt.legend()
plt.show()

# %%
possible_w = np.arange(-20, 20, 0.001)

# %%
possible_w
# Out:
# array([-20.   , -19.999, -19.998, ...,  19.997,  19.998,  19.999],
#       shape=(40000,))

# %%
possible_w.size
# Out:
# 40000

# %%
errors = []

for d in possible_w:
  e = erreur(x=n_chambres, w=d, y=prix)
  errors.append(e)

# %%
plt.plot(possible_w, errors)
plt.xlabel('les w possible')
plt.ylabel('erreur')
plt.show()

# %%
np.array(errors).min()
# Out:
# np.float64(304.3920140000027)

# %%
np.argmin(errors)
# Out:
# np.int64(25359)

# %%
possible_w[25359]
# Out:
# np.float64(5.359000000030992)

# %%
possible_w[np.argmin(errors)]
# Out:
# np.float64(5.359000000030992)

# %%
plt.scatter(data["n_chambres"], data['prix'], c="r")
plt.plot(data["n_chambres"], data['n_chambres'] * 5.359, label='w=5.359 (Le meilleur)')

plt.xlabel('Nombre de chambres')
plt.ylabel('Prix')
plt.legend()
plt.title('Prédiction du prix en fonction du nombre de chambres')
plt.show()

# %%
# Define the model
model_tf = Sequential([Dense(units=1, input_shape=[1])])

# Compile the model
model_tf.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.01), loss='mse')

# Display the model summary
model_tf.summary()
# Out:
# d:\Py\.venv\Lib\site-packages\keras\src\layers\core\dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_1 (Dense)                 │ (None, 1)              │             2 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2 (8.00 B)
#  Trainable params: 2 (8.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
# Prepare data for TensorFlow
X = data['n_chambres'].values
y = data['prix'].values

# %%
# Train the model
history_tf = model_tf.fit(X, y, epochs=500, verbose=0)

# Plot the training loss
plt.plot(history_tf.history['loss'])
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training Loss over Epochs')
plt.show()

# %%
# Make a prediction with the trained model
prediction = model_tf.predict(np.array([10]))
print(f"Prediction for 10 chambres: {prediction[0][0]}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# Prediction for 10 chambres: 47.99663543701172

# %%
t.lap()
# Out:
# Lap 1 : 00:00:35.59

# %%
import time

time.sleep(3)

# %%
t.stop()
# Out:
# Total : 00:00:38.61
