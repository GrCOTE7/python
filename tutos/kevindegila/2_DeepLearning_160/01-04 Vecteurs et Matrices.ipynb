# %%
import numpy as np
import pandas as pd

# %%
data = pd.DataFrame([ {"n_chambres" : 2, "superficie" : 40, "prix" : 10},
                     {"n_chambres" : 4,"superficie" : 35,  "prix" : 20},
                    {"n_chambres" : 3,"superficie" : 21,  "prix" : 15},
                     {"n_chambres" : 3,"superficie" : 18,  "prix" : 20},
                     {"n_chambres" : 1,"superficie" : 53,  "prix" : 3.5},
                    {"n_chambres" : 6,"superficie" : 75,  "prix" : 31},
                     {"n_chambres" : 5,"superficie" : 10,  "prix" : 33},
                    {"n_chambres" : 8,"superficie" : 46,  "prix" : 36},
                    {"n_chambres" : 7,"superficie" : 17,  "prix" : 50},
                    {"n_chambres" : 9,"superficie" : 100,  "prix" : 42},
                    ])
data

# %%
data.shape

# %%
X = data[["n_chambres", "superficie"]].values
X

# %%
X.shape

# %%
X.ndim # matrice # tenseur # tensor # tensorflow

# %%
n_chambre = data['n_chambres'].values
n_chambre

# %%
n_chambre.ndim # vecteur

# %%
np.array([X, X,X]).shape # tenseur

# %%
np.array([X, X,X]).ndim

# %%
maison = np.array([[  2,  40],
       [  4,  35],
       [  3,  21],
       [  3,  18]])
weights = np.array([0.23, 3])

# %%
maison[0] * weights, maison[0].dot(weights), sum(maison[0] * weights)  # Produit matriciel

# %%
prix = 0
for x, w in zip(maison, weights):
  prix = prix + x * w
prix

# %%
maison = np.array([
    [2, 1, 3],
    [0, -1, 4],
    [3, 1, -5]
])

# %%
maison.shape

# %%
W = np.array([2, 1, 3])

# %%
y = np.dot(maison, W)

# %%
y

# %%
maison @ W

# %%
y.shape

# %%
x = np.array([
    [1, 0, 2],
    [3, -1, 2]
])

# %%
x.shape

# %%
x.T

# %%
x.T.shape

# %%
dm_dw = X.T

dm_dx = W.T
