# %% [markdown]
# # Dict Views

# %%
scores: dict[str, int] = {
    "Alice": 85,
    "Bob": 92,
    "Charlie": 78
}

print(scores.keys())
print(scores.values())
print(scores.items())
print()    
for k, v in scores.items():
    print(f"{k}: {v} %")
# Out:
# dict_keys(['Alice', 'Bob', 'Charlie'])
# dict_values([85, 92, 78])
# dict_items([('Alice', 85), ('Bob', 92), ('Charlie', 78)])
#
# Alice: 85 %
# Bob: 92 %
# Charlie: 78 %

# %%
from collections.abc import ItemsView, KeysView, ValuesView

scores: dict[str, int] = {"Alice": 85, "Bob": 92, "Charlie": 78}

keys: KeysView[str] = scores.keys()
values: ValuesView[int] = scores.values()
items: ItemsView[str, int] = scores.items()

def show() -> None:
    print(keys)
    print(values)
    print(items)

show()

scores.update({"David": 88})
print()

show()
# Out:
# dict_keys(['Alice', 'Bob', 'Charlie'])
# dict_values([85, 92, 78])
# dict_items([('Alice', 85), ('Bob', 92), ('Charlie', 78)])
#
# dict_keys(['Alice', 'Bob', 'Charlie', 'David'])
# dict_values([85, 92, 78, 88])
# dict_items([('Alice', 85), ('Bob', 92), ('Charlie', 78), ('David', 88)])
